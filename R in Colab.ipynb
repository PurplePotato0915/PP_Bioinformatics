# %% [markdown]
# # Method 1

# %%
# %load_ext rpy2.ipython

# %%
# Every module should start with "%%R"
# %%R
R.Version()

# %% [markdown]
# # Method 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # How to reserve R packages in Gdrive

# %%
# %%R
# install.packages("harmony")

# %%
# %%R
# tar("library.tar.gz", "/usr/local/lib/R/site-library")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cp library.tar.gz /content/drive/MyDrive/R_packages/

# %% [markdown]
# reconnect the runtime

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(harmony)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cp drive/MyDrive/R_packages/library.tar.gz .

# %%
# !tar xf library.tar.gz
# Out:
# tar: Removing leading `/' from member names

# %%
# %%R
# .libPaths('usr/local/lib/R/site-library/')

# %%
# %%R
# library(harmony)
